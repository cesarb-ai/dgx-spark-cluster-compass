# %% [markdown]
# # `setup_guide.ipynb` → moved
#
# Setup is now split into **milestone notebooks** (`01`–`07`) plus one optional **all-in-one** console.
#
# | Start here | Purpose |
# |------------|---------|
# | **[`README.md`](README.md)** | Order of notebooks, layer map, install |
# | **`01_first_spark_power_lan_ssh.ipynb`** | Unbox → power → router (Cat6) → SSH |
# | … through **`07_…`** | Each next handshake |
# | **`08_full_stack_console.ipynb`** | Everything in one notebook (old wizard) |
#
# Open **`README.md`** in the `wizard` folder and follow the numbered path.
